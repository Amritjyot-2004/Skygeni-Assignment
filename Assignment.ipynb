# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd         #Pandas for data analytics
import numpy as np          #Numpy for numerical computation
import matplotlib.pyplot as plt     #Matplotlib for data visualization

# %% [markdown]
# Converting all csv files into their respective dataframes using read_csv function of pandas

# %%
fi = pd.read_csv(r"D:\Placement\Skygeni\finanical_information.csv")             #Dataframe for financial_information.csv
icd = pd.read_csv(r"D:\Placement\Skygeni\industry_client_details.csv")          #Dataframe for industry_client_details.csv
payinfo = pd.read_csv(r"D:\Placement\Skygeni\payment_information.csv")          #Dataframe for payment_information.csv
subinfo = pd.read_csv(r"D:\Placement\Skygeni\subscription_information.csv")     #Dataframe for subscription_information.csv

# %% [markdown]
# Printing first 5 rows of all dataframes using head function

# %%
fi.head()  #For fi dataframe
# Out:
#    Unnamed: 0  start_date    end_date  inflation_rate  gdp_growth_rate
# 0           0  01-01-2018  31-03-2018            5.77             3.51
# 1           1  01-04-2018  30-06-2018            1.17             2.15
# 2           2  01-07-2018  30-09-2018            1.56             1.82
# 3           3  01-10-2018  31-12-2018            2.78             2.43
# 4           4  01-01-2019  31-03-2019            6.91             3.44

# %%
icd.head()  #For icd dataframe
# Out:
#     client_id company_size         industry   location
# 0  4280387012        Large  Finance Lending     Mumbai
# 1  2095513148        Small  Finance Lending    Chennai
# 2  7225516707       Medium  Finance Lending  New Delhi
# 3  8093537819        Large      Block Chain     Mumbai
# 4  4387541014       Medium      Hyper Local   Banglore

# %%
payinfo.head() #For payinfo dataframe
# Out:
#     client_id payment_date  amount_paid payment_method
# 0  6292156167    9/16/2019        447.0  Bank Transfer
# 1  7462725203    5/21/2018        379.7  Bank Transfer
# 2  4698004907   09-11-2021        435.1          Check
# 3  3510240337   12-07-2020        413.1          Check
# 4  7501599785   03-04-2019         61.1  Bank Transfer

# %%
subinfo.head()  #For subinfo dataframe
# Out:
#     client_id subscription_type  start_date    end_date  renewed
# 0  1131383004            Yearly  11-11-2020  11-11-2021    False
# 1  4309371709           Monthly  24-05-2021  23-06-2021     True
# 2  3183675157            Yearly  25-12-2021  25-12-2022     True
# 3  5371694837           Monthly  14-03-2020  13-04-2020     True
# 4  5157113076           Monthly  07-11-2019  07-12-2019    False

# %% [markdown]
# Displaying information about each dataframe like number of rows, number of non-null values in each column, datatype fo every column etc. using info() function

# %%
fi.info()   #For fi dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21 non-null     int64
#  1   start_date       21 non-null     object
#  2   end_date         21 non-null     object
#  3   inflation_rate   21 non-null     float64
#  4   gdp_growth_rate  21 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 968.0+ bytes

# %%
icd.info()  #For icd dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   client_id     100 non-null    int64
#  1   company_size  100 non-null    object
#  2   industry      100 non-null    object
#  3   location      100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB

# %%
payinfo.info()   #For pay_info dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   client_id       100 non-null    int64
#  1   payment_date    100 non-null    object
#  2   amount_paid     100 non-null    float64
#  3   payment_method  100 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ KB

# %%
subinfo.info()   #For subinfo dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_id          100 non-null    int64
#  1   subscription_type  100 non-null    object
#  2   start_date         100 non-null    object
#  3   end_date           100 non-null    object
#  4   renewed            100 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %% [markdown]
# Calculating various statistical metrics for all numerical columns of all dataframes using describe() function

# %%
fi.describe() #For fi dataframe
# Out:
#        Unnamed: 0  inflation_rate  gdp_growth_rate
# count   21.000000       21.000000        21.000000
# mean    10.000000        4.426667         2.345238
# std      6.204837        2.245801         0.952747
# min      0.000000        0.760000         1.040000
# 25%      5.000000        2.710000         1.360000
# 50%     10.000000        4.400000         2.400000
# 75%     15.000000        6.760000         3.440000
# max     20.000000        7.710000         3.630000

# %%
icd.describe()  #For icd dataframe
# Out:
#           client_id
# count  1.000000e+02
# mean   5.663055e+09
# std    2.429520e+09
# min    1.077709e+09
# 25%    3.778644e+09
# 50%    5.508879e+09
# 75%    7.571385e+09
# max    9.842415e+09

# %%
payinfo.describe()  #For payinfo dataframe
# Out:
#           client_id  amount_paid
# count  1.000000e+02   100.000000
# mean   5.663055e+09   287.269000
# std    2.429520e+09   133.599908
# min    1.077709e+09    61.100000
# 25%    3.778644e+09   191.050000
# 50%    5.508879e+09   286.400000
# 75%    7.571385e+09   411.225000
# max    9.842415e+09   494.600000

# %%
subinfo.describe()  #For subinfo dataframe
# Out:
#           client_id
# count  1.000000e+02
# mean   5.663055e+09
# std    2.429520e+09
# min    1.077709e+09
# 25%    3.778644e+09
# 50%    5.508879e+09
# 75%    7.571385e+09
# max    9.842415e+09

# %% [markdown]
# Q1:How many finance lending and blockchain clients does the organization have?<br>
# Process: Following process is followed to obtain the answer:<br>
# 1) value_counts() function is used on industry column of icd dataframe which returns the count of all unique values present in that column in the form of pandas series.<br>
# 2) The obtained pandas series is assigned to cntOfIndus variable. As a result, cntOfIndus.index represents the list of unique values of industry column and cntOfIndus.values respresent their respective counts.<br>
# 3) To visualize the result, a bar graph is plotted with cntOfIndus.index on x axis and cntOfIndus.values on y axis.<br>
# 4) At last, the answer is returned by the values associated with finance lending and blockchain in cntOfIndus.<br>

# %%
#Using value_counts to return the count of unique values of industry column
cntOfIndus = icd['industry'].value_counts()
cntOfIndus
# Out:
# industry
# Block Chain        25
# Finance Lending    22
# Gaming             22
# Hyper Local        20
# AI                 11
# Name: count, dtype: int64

# %%
#Plotting the bar graph for visualization
plt.figure(figsize=(15,6))                                                                  #Setting the size of graph
plt.bar(cntOfIndus.index,cntOfIndus.values,color=['red','green','cyan','magenta','black'])  #Plotting bar graph
plt.xlabel("Industries of Clients")                                                         #Assigning label to x-axis
plt.ylabel('Count')                                                                         #Assigning label to y-axis
plt.title("Count of Client Industries")                                                     #Assigning title to the bar graph
plt.xticks(rotation = 0)                                                                    #Ensuring that the values of x-axis are displayed horizonatally
plt.show()

# %%
#Final answer to Q1
print(f"Q: How many finance lending and blockchain clients does the organization have?")
print(f"Number of Finance Lending clients: {cntOfIndus['Finance Lending']}")
print(f"Number of Blockchain clients: {cntOfIndus['Block Chain']}")
# Out:
# Q: How many finance lending and blockchain clients does the organization have?
# Number of Finance Lending clients: 22
# Number of Blockchain clients: 25

# %% [markdown]
# Q2: Which industry in the organization has the highest renewal rate?<br>
# Process: Following steps are followed to obtain the answer:<br>
# 1) Dataframes icd and subinfo are joined using inner join and the joined dataframe is assigned to the variable inner_join.<br>
# 2) Total number of renewals for each industry is calculated by grouping the inner_join dataframe on industry column and using count function on renewed column. The obtained answer is assigned to variable total_renewals.<br>
# 3) Number of true renewals for each industry is calculated by grouping the inner_join dataframe on industry column and filtering out the rows hanving value of renewed column as false and then using count function on industry column itself. The obtained answer is assigned to variable renewals_accepted.<br>
# 4) The renewal rates for each industry are calculated by dividing each value of renewals_accepted from that of total renewals and rounding them to 2 decimal places.<br>
# 5) A new dataframe df is created with columns as industry, total renewals, renewals accepted, renewals rejected and renewal rate which is further used to visualize the renewal rates for each industry on bar plot and number of renewals accepted and rejected on double bar plot.<br>
# 6) Finally the maximum renewal rate is calculated by using np.max() function on renewal rate column of df and the industry with highest renewal rate is obtained.

# %%
#Inner join for icd and subinfo dataframes on client id
inner_join = pd.merge(icd,subinfo, on="client_id", how = 'inner')
inner_join.head()
# Out:
#     client_id company_size         industry   location subscription_type  \
# 0  4280387012        Large  Finance Lending     Mumbai            Yearly
# 1  2095513148        Small  Finance Lending    Chennai           Monthly
# 2  7225516707       Medium  Finance Lending  New Delhi            Yearly
# 3  8093537819        Large      Block Chain     Mumbai           Monthly
# 4  4387541014       Medium      Hyper Local   Banglore           Monthly
#
#    start_date    end_date  renewed
# 0  25-11-2022  25-11-2023     True
# 1  03-11-2021  03-12-2021    False
# 2  19-01-2021  19-01-2022     True
# 3  14-09-2019  14-10-2019    False
# 4  08-11-2018  08-12-2018    False

# %%
#Grouping inner_join dataframe on industry column and finding total number of renewals for each industry by using count() function
total_renewals = inner_join.groupby('industry')['renewed'].count()
total_renewals
# Out:
# industry
# AI                 11
# Block Chain        25
# Finance Lending    22
# Gaming             22
# Hyper Local        20
# Name: renewed, dtype: int64

# %%
#Grouping inner_join dataframe on industry column and filtering out rows with value of renewed = false. 
# Also finding total number of renewals for each industry by using count() function.
df = inner_join.groupby('industry').apply(lambda group: group[group['renewed']== True]).reset_index(drop=True)
renewals_accepted = df['industry'].value_counts()
renewals_accepted
# Out:
# industry
# Gaming             16
# Finance Lending    12
# Block Chain        11
# Hyper Local         9
# AI                  7
# Name: count, dtype: int64

# %% [markdown]
# Since the indices for industry names in total_renewals.index list and renewals_accepted.index list were not in same position,so a new list ra was created which contains the count of accepted renewals for each industry in the same position corresponsing to that of total_renewals.index

# %%
ra = [renewals_accepted[i] for i in total_renewals.index]   #List containing the values of renewals_accepted
rr = [total_renewals[i]-renewals_accepted[i] for i in total_renewals.index] #List containing values of renewals rejected
rrate = [round(renewals_accepted[i]/total_renewals[i],2) for i in total_renewals.index] #List containing the renewal rates
df1 = pd.DataFrame({"Industry":total_renewals.index, "Total Renewals":total_renewals.values, "Renewals Accepted": ra, "Renewals Rejected":rr, "Renewal Rate":rrate})  #Creating the dataframe df
df1
# Out:
#           Industry  Total Renewals  Renewals Accepted  Renewals Rejected  \
# 0               AI              11                  7                  4
# 1      Block Chain              25                 11                 14
# 2  Finance Lending              22                 12                 10
# 3           Gaming              22                 16                  6
# 4      Hyper Local              20                  9                 11
#
#    Renewal Rate
# 0          0.64
# 1          0.44
# 2          0.55
# 3          0.73
# 4          0.45

# %%
#Visualizing renewals accepted and rejected using double bar plot

#Bar Positions
x = np.arange(len(df1['Industry']))     #Positions for x labels
width = 0.4                             #Width of the bars

#Plotting
plt.figure(figsize=(8, 5))
plt.bar(x - width/2, df1['Renewals Accepted'], width, label='True', color='green')
plt.bar(x + width/2, df1['Renewals Rejected'], width, label='False', color='red')
plt.xlabel('Industry')
plt.ylabel('Number of Renewals')
plt.title('Number of Renewals Accepted/Rejected for each Industry')
plt.xticks(x, df1['Industry'])  # Set x-ticks to category names
plt.legend()        #For displaying true and false labels on top right corner of figure
plt.show()

# %%
#Visualizing the renewal rates using bar plot
plt.figure(figsize=(10,6))
plt.bar(df1['Industry'],df1['Renewal Rate'], color=['red','green','cyan','magenta','black'])
plt.xlabel('Industry')
plt.ylabel('Renewal Rate')
plt.title("Industry Wise Renewal Rate")
plt.show()

# %%
#Calculating the max renewal rate and industry corresponding to it.
maxRRate = np.max(df1['Renewal Rate'])
res = ', '.join(df1[df1['Renewal Rate']==maxRRate]['Industry'].values)
#Final answer to Q2
print(f"Q: Which industry has highest renewal rate?")
print(f"{res} has highest renewal rate of {maxRRate}")
# Out:
# Q: Which industry has highest renewal rate?
# Gaming has highest renewal rate of 0.73

# %% [markdown]
# Q3: What was the average inflation rate when their subscriptions were renewed?<br>
# Process: The following steps are followed to obtain the answer<br>
# 1) Every value of the payment_date column of payinfo dataframe is converted into a datetime object. Same step was repeated for start_date and end_date columns of fi dataframe. This was done so as to check if payment_date lie in the range of start_date and end_date.<br>
# 2) The distribution of inflation rates for every start_date of fi dataframe is visualized using combo chart of bar and line plot.<br>
# 3) Dataframes payinfo and df are joined using inner join on client_id column so as to take into account the payment_dates of those clients for which the subscriptions are renewed.<br>
# 4) The inflation rates associated with the payment_dates that lie in the range of any start_date, end_date pair of fi dataframe was obtained in the list inf_rate and then a new column named inflation rate is added in the dataframe df containing same values as that of list inf_rate.<br>
# 5) Finally the average of the inflation rate column rounded off to 2 decimal places is calculated using np.mean() function.

# %%
#Converting every value of payment_date of payinfo dataframe to datetime object
from datetime import datetime
for i in range(len(payinfo['payment_date'])):
    if(payinfo['payment_date'][i][1]=='/'or payinfo['payment_date'][i][2]=='/'):
        payinfo['payment_date'][i] = datetime.strptime(payinfo['payment_date'][i], "%m/%d/%Y")  #Parsing the string into datetime object using same format as that of string
    else:
        payinfo['payment_date'][i] = datetime.strptime(payinfo['payment_date'][i], "%d-%m-%Y")  #Parsing the string into datetime object using same format as that of string
payinfo.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2848\19057532.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payinfo['payment_date'][i] = datetime.strptime(payinfo['payment_date'][i], "%m/%d/%Y")  #Parsing the string into datetime object using same format as that of string
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2848\19057532.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payinfo['payment_date'][i] = datetime.strptime(payinfo['payment_date'][i], "%m/%d/%Y")  #Parsing the string into datetime object using same format as that of string
# ...

# %%
#Visualizing the inflation rate for each start date using combo chart
plt.figure(figsize=(10,80))
fig, ax = plt.subplots()        # Create the figure and axis

# Plot bar chart
ax.bar(fi['start_date'], fi['inflation_rate'], color = 'blue')
ax.set_ylabel('Inflation Rate')
ax.set_xlabel('Start Date')

#Setting labels for x axis
ax.set_xticks(range(len(fi['start_date'])))
ax.set_xticklabels(fi['start_date'], rotation=90)

#Plot the line chart
ax1 = ax.twinx()    #Creating second y axis
ax1.plot(fi['start_date'], fi['inflation_rate'], color='red', marker='o')
ax1.set_ylabel('Inflation Rate')

plt.title("Combo Chart for Inflation Rate")
plt.show()

# %%
#Converting every value of payment_date of payinfo dataframe to datetime object
for i in range(21):
    fi['start_date'][i] = datetime.strptime(fi['start_date'][i], "%d-%m-%Y")    #Parsing the string into datetime object using same format as that of string
    fi['end_date'][i] = datetime.strptime(fi['end_date'][i],"%d-%m-%Y")         #Parsing the string into datetime object using same format as that of string
fi.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2848\643002748.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi['start_date'][i] = datetime.strptime(fi['start_date'][i], "%d-%m-%Y")    #Parsing the string into datetime object using same format as that of string
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2848\643002748.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi['end_date'][i] = datetime.strptime(fi['end_date'][i],"%d-%m-%Y")         #Parsing the string into datetime object using same format as that of string
# ...

# %%
#Inner join of payinfo and df
df2 = pd.merge(payinfo,df,on='client_id',how = 'inner')
df2
# Out:
#      client_id         payment_date  amount_paid payment_method company_size  \
# 0   6292156167  2019-09-16 00:00:00        447.0  Bank Transfer        Small
# 1   7462725203  2018-05-21 00:00:00        379.7  Bank Transfer       Medium
# 2   3510240337  2020-07-12 00:00:00        413.1          Check       Medium
# 3   8719792472  2018-10-02 00:00:00         73.8    Credit Card       Medium
# 4   3325348894  2019-09-07 00:00:00        348.1    Credit Card        Small
# 5   9031632460  2019-06-07 00:00:00        222.9          Check        Small
# 6   4280387012  2022-11-25 00:00:00         77.1          Check        Large
# 7   1089413096  2019-04-21 00:00:00        453.6    Credit Card        Large
# 8   5536015034  2019-11-15 00:00:00         65.4    Credit Card        Small
# 9   3183675157  2021-12-25 00:00:00        261.1  Bank Transfer        Small
# 10  3683504527  2018-12-04 00:00:00        202.4          Check       Medium
# ...

# %%
#Obtaining the inflation rates associated with the payment_dates lying in range of any start_date - end_date pairs.
inf_rate = []
for i in df2['payment_date']:
    for j in range(21):
        if fi['start_date'][j]<=i<=fi['end_date'][j]:
            inf_rate.append(fi['inflation_rate'][j])
df2['inflation_rate'] = inf_rate
df2.head()
# Out:
#     client_id         payment_date  amount_paid payment_method company_size  \
# 0  6292156167  2019-09-16 00:00:00        447.0  Bank Transfer        Small
# 1  7462725203  2018-05-21 00:00:00        379.7  Bank Transfer       Medium
# 2  3510240337  2020-07-12 00:00:00        413.1          Check       Medium
# 3  8719792472  2018-10-02 00:00:00         73.8    Credit Card       Medium
# 4  3325348894  2019-09-07 00:00:00        348.1    Credit Card        Small
#
#           industry   location subscription_type  start_date    end_date  \
# 0      Block Chain     Mumbai            Yearly  16-09-2019  15-09-2020
# 1      Hyper Local   Banglore           Monthly  21-05-2018  20-06-2018
# 2  Finance Lending   Banglore            Yearly  07-12-2020  07-12-2021
# 3      Hyper Local  Hyderabad            Yearly  10-02-2018  10-02-2019
# 4      Hyper Local   Banglore           Monthly  09-07-2019  08-08-2019
#
#    renewed  inflation_rate
# 0     True            7.71
# ...

# %%
#Final answer of Q3
print(f"Q: What was the average inflation rate when their subscriptions were renewed?")
print(f"The average inflation rate when their subscriptions were renewed was {round(np.mean(df2['inflation_rate']),2)}")
# Out:
# Q: What was the average inflation rate when their subscriptions were renewed?
# The average inflation rate when their subscriptions were renewed was 4.47

# %% [markdown]
# Q4:What is the median amount paid each year for all payment methods?<br>
# Process: Following steps are followed to obtain the answer:<br>
# 1) From all values of payement_date column of payinfo dataframe, years are extracted and stored in Years list. this was done to calculate median amount for each year.<br>
# 2) A new column named Years is added to the dataframe payinfo using years list.<br>
# 3) The median amount for each year for all payment methods is calculated by grouping the dataframe payinfo by columns Year and payment_method and applying median function on amount_paid column.<br>
# 4) The grouped dataframe is converted to dataframe with columns as Years, Payment Methods and Median Amounts.<br>
# 5) The obtained dataframe is used to visualize the distribution of the total median amount per year over each payment method using pie charts.<br>
# 6) Finally the dataframe is displayed as answer.<br>

# %%
#Extracting years from payment_dates
Years = [payinfo['payment_date'][i].year for i in range(len(payinfo))]
Years[0:10]
# Out:
# [2019, 2018, 2021, 2020, 2019, 2018, 2019, 2019, 2019, 2022]

# %%
#Adding column year in payinfo dataframe
payinfo['Year'] = Years
payinfo.head()
# Out:
#     client_id         payment_date  amount_paid payment_method  Year
# 0  6292156167  2019-09-16 00:00:00        447.0  Bank Transfer  2019
# 1  7462725203  2018-05-21 00:00:00        379.7  Bank Transfer  2018
# 2  4698004907  2021-11-09 00:00:00        435.1          Check  2021
# 3  3510240337  2020-07-12 00:00:00        413.1          Check  2020
# 4  7501599785  2019-04-03 00:00:00         61.1  Bank Transfer  2019

# %%
#Grouping payinfo dataframe by columns Year and payment_method and applying median function on amount_paid column
df4 = payinfo.groupby(['Year','payment_method'])['amount_paid'].median()

# %%
#Creating the dataframe for visualizing
years = [i[0] for i in df4.index]
pay_meth = [i[1] for i in df4.index]
med_amt = df4.values
df4 = pd.DataFrame({"Years":years,"Payment Methods":pay_meth,"Median Amount":med_amt})
df4.head()
# Out:
#    Years Payment Methods  Median Amount
# 0   2018   Bank Transfer         281.65
# 1   2018           Check         216.60
# 2   2018     Credit Card         229.15
# 3   2019   Bank Transfer         184.20
# 4   2019           Check         410.20

# %%
#Visualizing the dataframe using piecharts
year = df4['Years'].unique()        #Gives unique values for years column

for yr in year:
    df_year = df4[df4['Years'] == yr]  #Returns a dataframe of rows where year column as value = yr
    total = round(df_year['Median Amount'].sum(),2)     #Calculates total median amount for year yr
    plt.figure(figsize=(6, 6))
    plt.pie(
        df_year['Median Amount'], 
        labels=df_year['Payment Methods'], 
        autopct='%1.1f%%',                  #Format to show amounts as percentage on pie chart               
        startangle=90, 
        colors=['Red', 'Green', 'Blue']
    )
    plt.title(f'Median Amount Distribution in {yr}\nTotal Median Amount:{total}')
    plt.show()

# %%
#Final answer of Q4
print(f"Q: What is the median amount paid each year for all payment methods?")
print(f"Following is the median amount paid each year for all payment methods:")
df4
# Out:
# Q: What is the median amount paid each year for all payment methods?
# Following is the median amount paid each year for all payment methods:
#     Years Payment Methods  Median Amount
# 0    2018   Bank Transfer         281.65
# 1    2018           Check         216.60
# 2    2018     Credit Card         229.15
# 3    2019   Bank Transfer         184.20
# 4    2019           Check         410.20
# 5    2019     Credit Card         401.90
# 6    2020   Bank Transfer         225.10
# 7    2020           Check         413.10
# 8    2020     Credit Card         285.25
# 9    2021   Bank Transfer         255.30
# 10   2021           Check         435.10
# 11   2021     Credit Card         208.70
# 12   2022   Bank Transfer         196.50
# 13   2022           Check         275.50
# 14   2022     Credit Card         326.20
